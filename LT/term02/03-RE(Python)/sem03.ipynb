# %% [markdown]
# #### Задача 1.
#
# Найдите в тексте все телефонные номера. Номера могут быть в формате 0(000)00-00-00 или 0 000 00 00 00.
#
# Find all phone numbers in text. The numbers can be in the formats above.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Программа ждет, что пользователь введет адрес электронной почты. Предполагается, что адрес может содержать только латинские буквы, цифры и нижнее подчеркивание, обязательно содержит @ и имя домена через точку. Других точек в адресе нет. Программа должна проверять, что пользователь ввел именно такой адрес, и предупреждать, если что-то неладно. Используйте fullmatch.
#
# The program expects that the user will enter an email. It is supposed that the address can contain only latin letters, numbers and '\_' sign, must contain @ and domain name (e.g. _ru_) after a full stop. There are no other full stops in the adress. The program must check if the user has entered the right email address and warn if something is amiss. Use re.fullmatch.

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Цензура: в тексте встречается слово *война* и разные его вариации в падежах (и регистр тоже везде разный). Замените это слово по всему тексту на многоточие.
#
# There is a Russian word 'война' in a text (it can have different word forms and be written in different cases, full paradigm [here](https://ru.wiktionary.org/wiki/%D0%B2%D0%BE%D0%B9%D0%BD%D0%B0)). Replace all occurrences of this word to '...' in the text.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# В тексте встречаются нецелые числа (можно через запятую, можно через точку, а можете учесть оба варианта). Нужно все числа в тексте округлить до двух знаков после запятой(точки), причем не просто отрезать хвост: 2.467 должно превращаться в 2.47.
#
# There are floating point numbers in a text (e.g., they can be written as 23.9456 or as 23,9456). All these numbers must be rounded to 2 digits after the sign, according to math rules: 2.467 becomes 2.47, not 2.46. Use re.sub.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# Найти ценники в формате "10000 руб. 00 коп.", при этом:
# - "руб." и "коп." не обязательно сокращены;
# - кол-во копеек не может быть трёхзначным;
# - кол-во рублей может быть нулевым, но не может быть некорректно записанным числом типа "0123 рубля")
#
# Find all prices in a text which have a format like "10000 руб. 00 коп.". Mind that:
# - "руб." and "коп." can be written fully: "рубля", "рублей", "копейки", "копеек"...
# - the quantity of коп. must be 1 or 2 digits
# - the quantity of руб. can be zero, but can't be a number with leading zero as 0123 (only 123 is valid)

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Некоторые любят выделять особо важные места в тексте с помощью нижнего подчёркивания, например: "...здесь \_очень важно\_ отметить..." (дело в том, что нижние подчеркивания в некоторых редакторах автоматически превращаются в курсив).
#
# Ищем такие выделения, но не длиннее 5 слов.
#
# Some people like to highlight the most important words in a text with the help of the sign '\_', e.g. "here it is \_very important\_ to say..." (the reason for this is that some text editors automatically replace such things to italics).
#
# Let's find such highlights, but they cannot be longer than 5 words.

# %%
# your code here

# %% [markdown]
# #### Задача 7.
#
# Найти в тексте все куски, которые взяты в круглые скобки. Считаем, что вложенных скобок нет.
#
# Find all the parts in a text which are in round brackets. We suppose that there are no nested brackets.

# %%
# your code here

# %% [markdown]
# #### Задача 8.
#
# В текстовом файле находятся пути к другим файлам. Каждый путь устроен таким образом, что у него обязательно есть расширение через точку, название собственно файла и как минимум папка, в которой он находится, например:
#
#     myfolder/myfile.txt
#     C:\Python\files\script.py
#     ...
#
# Обратите внимание, что слеш может быть в любую сторону (в Windows он обратный, в Unix-системах прямой). Напишите такое регулярное выражение, которое будет в поиске re.findall возвращать кортежи вида ('все, что слева от имени файла', 'имя файла', 'расширение'). Для примеров:
#
#     ('myfolder', 'myfile', 'txt')
#     ('C:\Python\files', 'script', 'py')
#
# There are filepaths in a text file. Each filepath definitely has an extension, a name of the file and at least one folder where the file is. The slash sign can be either \\ or / (it's because in Windows we use backslash and in Unix systems, like Linux or MacOS, it's /). Compile such a regular expression that re.findall with it will return tuples of the kind above (with three strings in each tuple).

# %%
# your code here
