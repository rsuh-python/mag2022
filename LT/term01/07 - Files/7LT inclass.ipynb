# %%
import math
import string
import collections
import functools
import itertools
import re

import os, sys

import pandas as pd  # pd.DataFrame
import numpy as np

# %%
from math import sqrt
from math import *  # from nltk.book import *

# %%
pi = 6

math.__name__
# Out:
# 'math'

# %%
if __name__ == '__main__':
  ...

# %%
# !pip install pandas # python -m pip install pandas 
# python3 -m pip install pandas
# conda

# %%
# !pip install rnnmorph

# %%
r'C:\Python\files\text.txt'

encoding='cp1251', 'cp1252', 'utf8', 'utf16', 'utf32'

path = r''

mode == 'r', 'w', 'a', 'rb', 'wb', 'ab'

open(path, mode, encoding)

# %%
f = open(r'/content/Толстой Лев. Война и мир. Книга 1 - royallib.ru.txt', 'r', encoding='cp1251')

# %%
out = open('myfile.txt', 'a', encoding='utf8')

# %%
out.write('Write this string\n')
out.writelines(['string 1\n', 'string 2\n'])
print('print this string', sep='', end='\n', file=out)

# %%
out.close()

# %%
for line in f:
  print(line.rstrip('\n'), file=out)

# %%
# f.readline() 
# f.read()
# f.readlines() ['', '', '']

# %%
f.close()

# %%
import locale

locale.getpreferredencoding()
# Out:
# 'UTF-8'

# %%
path = '/content/Толстой Лев. Война и мир. Книга 1 - royallib.ru.txt'

# %%
with open(path, 'r', encoding='cp1251') as file:
  with open('myfile.txt', 'w') as file2:
    i = 0
    for line in file:
      if i > 10:
        break
      print(line.rstrip(), file=file2)
      i += 1

# %%
import os

# %%
os.listdir('/content')  # '/content' + name

# %%
os.remove(path)
os.rmdir(path)
os.mkdir(path)

# %%
os.makedirs('/content/outer/myfolder')

# %%
os.path.exists('/content/unknown')
# Out:
# False

# %%
os.path.isdir('/content/outer/myfolder')
# Out:
# True

# %%
os.path.isfile(path)

# %%
# 'pythonscripts' 'myfiles/text.txt'
# 'C:\Python\pythonscripts\myfiles\text.txt'
# 'home\usr\....'

# %%
# os.path.isabs(path)
# os.path.abspath(path)
os.path.splitext(r'C:\Python\pythonscripts\myfiles\text.txt')[1]
# Out:
# '.txt'

# %%
os.path.split('/content/outer/myfolder')
# Out:
# ('/content/outer', 'myfolder')

# %%
os.path.basename('/content/outer/myfolder.txt')
# Out:
# 'myfolder.txt'

# %%
os.path.dirname('/content/outer/myfolder')
# Out:
# '/content/outer'

# %%
os.path.join('/content', 'myfile.txt')
# Out:
# '/content/myfile.txt'

# %%
import pickle

# %%
dct = {x: x ** 2 for x in range(1, 11)}

# %%
pickle.dump(dct, open('dct.bin', 'wb'))

# %%
new = pickle.load(open('dct.bin', 'rb'))

# %%
new
# Out:
# {'1': 1,
#  '2': 4,
#  '3': 9,
#  '4': 16,
#  '5': 25,
#  '6': 36,
#  '7': 49,
#  '8': 64,
#  '9': 81,
#  '10': 100}

# %%
import json

# %%
with open('myfile.json', 'w', encoding='utf8') as file:
  json.dump(dct, file, ensure_ascii=False)

# %%
with open('myfile.json', 'r', encoding='utf8') as file:
  new = json.load(file)
