# %% [markdown]
# Итак, вот и наше первое домашнее задание!
#
# Выполнять его можно прямо в этой тетрадке и потом отправить мне ее по почте, или можете завести отдельный скрипт .py (чтобы потренироваться это делать) и сделать все в нем (одну задачу в скрипте, то есть, вам понадобится два файла .py), это не принципиально. Обратите внимание на ячейку кода, в которой написано # your code here: решеточками в питоне обозначают *комментарии* (то есть то, что интерпретатор игнорирует и никак не реагирует на это). Вы можете сами себе оставлять такие комментарии, например:

# %%
print('Это моя функция')  # print выводит что-то в печать

# %% [markdown]
# Мой комментарий про "ваш код туточки", естественно, можно просто стереть и вписать вместо него свой код, а можно оставить, он ничего не делает. Только не вписывайте свои команды ему в хвост :) # говорит питону, чтобы он игнорировал все, что после нее и до конца строки.
#
# В первом дз у вас только две супер-простые задачки, ваша главная цель - разобраться с установкой всего нужного и освоиться в самом питоне и в выбранной вами среде разработки.

# %% [markdown]
# #### Задача 1.
#
# Напишите программу, которая спросит у человека сперва его имя, потом фамилию, потом возраст, а потом все это выведет на экран. Подумайте, как вывести все в виде:
#
# Имя: Вася
#
# Фамилия: Пупкин
#
# Возраст: 23

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Напишите программу, которая сложит три любых числа и выведет на экран сообщение о том, что сумма числа 1, числа 2 и числа 3 (числа нужно вывести) равна стольки-то.

# %%
# your code here
