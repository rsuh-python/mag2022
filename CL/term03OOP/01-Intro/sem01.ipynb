# %% [markdown]
# #### Задача 1 (5 баллов).
#
# Давайте опять поимитируем деятельность лингвистов. У нас с вами должен быть класс "лингвист вообще", у которого есть имя, возраст, аффилиация (вуз), зарплата, стаж и список публикаций (пополняемый). Все лингвисты ходят на работу, где проводят время (что они там делают - это уже отличается), все ездят на конференции, все пишут статьи и читают научную литературу. Всем лингвистам босс может увеличить зарплату (приятное!).
#
# Есть также два класса-ребенка: "компьютерный лингвист" и "теоретический лингвист". Первый умеет еще и программировать: поэтому у него также есть репозиторий на гитхабе с его рабочими проектами. На работе он пишет код или статьи (можно организовать с помощью рандома). Второй ездит в полевые экспедиции. И тому, и другому для написания новой статьи нужно наработать материал: первый кодит, второй собирает данные в экспедициях.
#
# Включите фантазию, необязательно строго следовать моим описаниям, хотите добавить вашим лингвистам еще что-то - добавляйте! Главное условие - чтобы был один родительский класс и два класса-ребенка. Если мне очень понравится, как нафантазировали, будет + балл.)

# %%
# your code here
