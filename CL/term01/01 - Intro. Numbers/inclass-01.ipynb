# %%
a = 1

# %%
id(a)
# Out:
# 11256064

# %%
# hashable // immutable

# %%
a += 1

# %%
type(a)
# Out:
# int

# %%
a is 2
# Out:
# True

# %%
b = 1024

# %%
b is 1024
# Out:
# False

# %%
b = 3

# %%
type(b)
# Out:
# float

# %%
# + - * / // % **
# Out:
# 1

# %%
0.1 * 0.1  # 1/3 = 0.3333...
# Out:
# 0.010000000000000002

# %%
# complex

# %%
# > < == >= <= !=

# %%
print(a, b)
# Out:
# 2 3

# %%
if a == 0:
  print(0)
  if b == 0:
    print(b)
  else:
    print(0)
elif a == 1:
  print(1)
else:
  print(a)
# Out:
# 2

# %%
if a:  # bool('') 
  print('b')
# Out:
# b

# %%
c = a != b

# %%
type(c)
# Out:
# bool

# %%
# True False

# %%
d = 'True'

# %%
bool(0)
# Out:
# False

# %%
print(1, 2, 3, 4, 5, 6, 7, 8)
# Out:
# 1 2 3 4 5 6 7 8

# %%
print(1, 2, 3, sep=':', end='!\n')
print(345)
# Out:
# 1:2:3!
# 345

# %%
a = 1
b = 2
c = 3

print(f'variable a: {a}\nvariable b: {b}\nvariable c: {c}')
# Out:
# variable a: 1
# variable b: 2
# variable c: 3

# %%
a = 4.5667788
round(a, 2)
# Out:
# 4.57

# %%
a = 'bac'

# %%
a[0]
# Out:
# 'a'

# %%
int(input())
# Out:
# 2.0
